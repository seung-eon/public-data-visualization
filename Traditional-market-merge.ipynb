# %% [markdown]
# ## 전통시장 위치와 편의시설

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 한글, -(마이너스) 깨짐 없이 보기
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %%
# 폰트가 선명하게 보이도록 설정
from IPython.display import set_matplotlib_formats

set_matplotlib_formats("retina")

# %%
# 확인
pd.Series([-1, 0, 1, 3, 5]).plot(title="한글폰트")
# Out:
# <AxesSubplot:title={'center':'한글폰트'}>

# %%
# 위경도 포함된 데이터 불러오기
df1 = pd.read_csv("data/서울시 전통시장 현황.csv", encoding='CP949')
df1.shape
# Out:
# (330, 6)

# %%
df1.head(1)
# Out:
#    자치구 코드 자치구명 전통시장명         주소명         위도          경도
# 0      22  은평구  갈현시장  갈현동 424-16  37.623587  126.917385

# %%
df1.isnull().sum()
# Out:
# 자치구 코드    0
# 자치구명      0
# 전통시장명     0
# 주소명       0
# 위도        0
# 경도        0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구 코드  330 non-null    int64
#  1   자치구명    330 non-null    object
#  2   전통시장명   330 non-null    object
#  3   주소명     330 non-null    object
#  4   위도      330 non-null    float64
#  5   경도      330 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 15.6+ KB

# %%
# df 1 컬럼 정리
columns1 = ['자치구명', '전통시장명', '주소명', '경도', '위도']

df1 = df1[columns1].copy()
df1.shape
# Out:
# (330, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    330 non-null    object
#  1   전통시장명   330 non-null    object
#  2   주소명     330 non-null    object
#  3   경도      330 non-null    float64
#  4   위도      330 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 13.0+ KB

# %%
# 컬럼 이름 변경
df1.columns = ['구', '시장명', '주소명', '경도', '위도']
df1.head()
# Out:
#      구             시장명          주소명          경도         위도
# 0  은평구            갈현시장   갈현동 424-16  126.917385  37.623587
# 1  강남구            강남시장    신사동510-11  126.953488  37.496746
# 2  동작구            강남시장      상도동 488  127.020640  37.518749
# 3  강남구       강남역 지하도상가     역삼동821-1  127.028026  37.498595
# 4  서초구  강남터미널지하도상점가1구역  서초구 반포동 163  126.986060  37.500478

# %%
# 시장 이름에 '시장'이 들어가는 데이터만 보기

df_market = df1["시장명"].str.contains("시장").copy()
df_market.value_counts()
# Out:
# True     263
# False     67
# Name: 시장명, dtype: int64

# %%
# 시장 이름에 '시장'이 들어가는 데이터만 추출

df_mk = df1.loc[df1["시장명"].str.contains("시장")].copy()
df_mk.head(10)
# Out:
#        구       시장명            주소명          경도         위도
# 0    은평구      갈현시장     갈현동 424-16  126.917385  37.623587
# 1    강남구      강남시장      신사동510-11  126.953488  37.496746
# 2    동작구      강남시장        상도동 488  127.020640  37.518749
# 7    강북구  강북종합골목시장  수유3동 177번지 일대  127.027052  37.640568
# 8    강북구    강북종합시장     수유3동 179-5  127.025634  37.642037
# 9    구로구    개봉중앙시장     개봉2동 324-1  126.853884  37.491665
# 13  동대문구      경동시장       제기동 1018  127.039542  37.578912
# 14   양천구      경창시장  양천구 신월동 447-8  126.842090  37.524924
# 15   강동구    고덕전통시장     고덕동 210-3   127.168918  37.557587
# 17   구로구    고척근린시장     고척동 257-12  126.850506  37.502404

# %%
# 구별 시장 수 막대그래프

plt.figure(figsize=(15, 4))
sns.countplot(data=df_mk, x="구")
# Out:
# <AxesSubplot:xlabel='구', ylabel='count'>

# %%
df_mk[["위도", "경도"]].plot.scatter(x="경도", y="위도")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
sns.scatterplot(data=df_mk, x="경도", y="위도", hue="구")

# 레전드값 옆으로
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# 편의시설 데이터 불러오기
df2 = pd.read_csv('data/전통시장현황_20200226..csv', encoding='CP949')
df2.shape
# Out:
# (1450, 76)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 76 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   시장형태                                                                 1450 non-null   object
#  1   등록형태                                                                 1450 non-null   object
#  2   시도                                                                   1450 non-null   object
#  3   시군구                                                                  1450 non-null   object
#  4   시장명                                                                  1450 non-null   object
#  5   주소(지번)                                                               1450 non-null   object
#  6   주소(도로명)                                                              1450 non-null   object
#  7   시장크기 (1=대형시장, 2=중대형시장, 3=중형시장, 4=소형시장)                               1450 non-null   int64
#  8   시장면적(단위선택: 1=제곱미터, 2=평형)                                             1450 non-null   int64
#  9   시장면적(㎡)                                                              1450 non-null   object
#  10  시장면적(평)                                                              114 non-null    float64
#  11  소유형태(1=법인시장, 2=개인시장, 3=공설시장, 4=공동시장)                                 1450 non-null   int64
#  12  외부형태(전통시장: 1=상가건물형, 2=노점형, 3=장옥형, 4=상가주택형)                           1450 non-null   int64
#  13  개설주기(1=상설, 2=정기, 3=상설+정기)                                            1450 non-null   int64
#  14   정기(장날1)                                                             163 non-null    float64
#  15   정기(장날2)                                                             162 non-null    float64
#  16  상설+정기(장날1)                                                           260 non-null    float64
#  17   상설+정기(장날2)                                                          260 non-null    float64
#  18  전체점포수                                                                1450 non-null   object
#  19  영업점포수(합)                                                             1450 non-null   object
#  20  영업점포수(임차점포수)                                                         1450 non-null   object
#  21  비영업 점포수(빈점포)                                                         1450 non-null   int64
#  22  비영업 점포수(기타점포)                                                        1450 non-null   int64
#  23   노점수                                                                 1450 non-null   int64
#  24  2017년-점포소유상인                                                         1450 non-null   int64
#  25  2017년-점포임차상인                                                         1450 non-null   int64
#  26  2017년-종업원수                                                           1450 non-null   int64
#  27  2017년-노점상인수                                                          1450 non-null   int64
#  28  2017년-총시장상인                                                          1450 non-null   int64
#  29   상인회 운영여부(1=운영, 2=미운영)                                               1450 non-null   int64
#  30   상인회 조직형태(1=시군구청 등록 상인회, 2=상점가진흥조합, 3=사업조합 또는 협동조합, 4=사단법인, 5=임의단체)  1352 non-null   float64
#  31  상근직원 명수                                                              851 non-null    float64
#  32  상인회 회원 수                                                             1352 non-null   object
#  33  보유현황 - 1고객지원센터(1=있음, 2=없음)                                           1450 non-null   int64
#  34  보유현황 - 2유아놀이방(어린이놀이터)(1=있음, 2=없음)                                    1450 non-null   int64
#  35  보유현황 - 4고객휴게실(1=있음, 2=없음)                                            1450 non-null   int64
#  36  보유현황 - 5수유센터(1=있음, 2=없음)                                             1450 non-null   int64
#  37  보유현황 - 6물품보관함(1=있음, 2=없음)                                            1450 non-null   int64
#  38  보유현황 - 7자전거보관함(1=있음, 2=없음)                                           1450 non-null   int64
#  39  보유현황 - 10쇼핑카트(1=있음, 2=없음)                                            1450 non-null   int64
#  40  문2) 보유현황 - 12고객동선통로(1=있음, 2=없음)                                      1450 non-null   int64
#  41  보유현황 - 16시장전용 고객주차장(1=있음, 2=없음)                                      1450 non-null   int64
#  42  보유갯수 - 16시장전용 고객주차장                                                  1095 non-null   float64
#  43  보유여부 - 2소화전(1=있음, 2=없음)                                              1450 non-null   int64
#  44  보유개수-2소화전                                                            1371 non-null   float64
#  45  보유여부 - 3공용소화기(1=있음, 2=없음)                                            1450 non-null   int64
#  46  보유개수 - 3공용소화기                                                        1399 non-null   float64
#  47  보유여부 - 5경보기(1=있음, 2=없음)                                              1450 non-null   int64
#  48  보유개수 - 5경보기                                                          1205 non-null   float64
#  49  화재/가스감지센서(1=있음, 2=없음)                                                1450 non-null   int64
#  50  보유개수 -화재/가스 감지센서                                                     1170 non-null   float64
#  51  보유여부 - 7자동 화재속보 설비(1=있음, 2=없음)                                       1450 non-null   int64
#  52  보유개수 - 7자동화재속보설비                                                     555 non-null    float64
#  53  보유여부 - 1CCTV(1=있음, 2=없음)                                             1450 non-null   int64
#  54  보유여부 - 2공동수도시설(노점/장옥형)(1=있음, 2=없음)                                   188 non-null    float64
#  55  보유여부 - 3공동화장실(1=있음, 2=없음)                                            1450 non-null   int64
#  56  보유개수 -3공동화장실                                                         1357 non-null   float64
#  57  보유여부 - 4아케이드(1=있음, 2=없음)                                             1450 non-null   int64
#  58  보유여부 - 5냉방시설(1=있음, 2=없음)                                             740 non-null    float64
#  59  보유여부 - 6난방시설(1=있음, 2=없음)                                             740 non-null    float64
#  60  보유여부 - 7가스시설(1=있음, 2=없음)                                             1450 non-null   int64
#  61  보유여부 - 8엘리베이터/에스컬레이터(건물형만)(1=있음, 2=없음)                               740 non-null    float64
#  62  보유여부 - 9장애인용 화장실(1=있음, 2=없음)                                         1450 non-null   int64
#  63  보유여부 - 10배수시설(1=있음, 2=없음)                                            1450 non-null   int64
#  64  보유여부 - 11실외 가로등(1=있음, 2=없음)                                          1450 non-null   int64
#  65  보유여부 - 12전기배선시설(1=있음, 2=없음)                                          1450 non-null   int64
#  66  보유여부 - 13건물실내조명 (LED조명 설치 여부)(1=LED조명, 2=형광등 및 백열등)                  805 non-null    float64
#  67  보유여부 - 13건물실내조명 (LED조명 설치 여부)(1=LED조명, 2=형광등 및 백열등).1                997 non-null    float64
#  68  보유여부 - 1이동/고정식,이벤트 광장(1=있음, 2=없음)                                    1450 non-null   int64
#  69  보유여부 - 2테마거리(1=있음, 2=없음)                                             1450 non-null   int64
#  70  보유여부 - 3TV광고판(1=있음, 2=없음)                                            1450 non-null   int64
#  71  보유여부 - 4LED광고판(1=있음, 2=없음)                                           1450 non-null   int64
#  72  보유여부 - 6아치/조형물(1=있음, 2=없음)                                           1450 non-null   int64
#  73  시장/상점가의 주력 상품 여부(1=있음, 2=없음)                                         1450 non-null   int64
#  74  시장/상점가의 주력 상품의 개수(1=1개, 2=2개, 3=3개, 4=4개 이상)                         419 non-null    float64
#  75  시장/상점가의 주력 상품의 상품명                                                   419 non-null    object
# dtypes: float64(21), int64(42), object(13)
# memory usage: 861.1+ KB

# %%
# 컬럼 보기
df2.columns
# Out:
# Index(['시장형태', '등록형태', '시도', '시군구', '시장명', '주소(지번)', '주소(도로명)',
#        '시장크기 (1=대형시장, 2=중대형시장, 3=중형시장, 4=소형시장)', '시장면적(단위선택: 1=제곱미터, 2=평형)',
#        '시장면적(㎡)', '시장면적(평)', '소유형태(1=법인시장, 2=개인시장, 3=공설시장, 4=공동시장)',
#        '외부형태(전통시장: 1=상가건물형, 2=노점형, 3=장옥형, 4=상가주택형)',
#        '개설주기(1=상설, 2=정기, 3=상설+정기)', ' 정기(장날1)', ' 정기(장날2)', '상설+정기(장날1)',
#        ' 상설+정기(장날2)', '전체점포수', '영업점포수(합)', '영업점포수(임차점포수)', '비영업 점포수(빈점포)',
#        '비영업 점포수(기타점포)', ' 노점수', '2017년-점포소유상인', '2017년-점포임차상인', '2017년-종업원수',
#        '2017년-노점상인수', '2017년-총시장상인', ' 상인회 운영여부(1=운영, 2=미운영)',
#        ' 상인회 조직형태(1=시군구청 등록 상인회, 2=상점가진흥조합, 3=사업조합 또는 협동조합, 4=사단법인, 5=임의단체)',
#        '상근직원 명수', '상인회 회원 수', '보유현황 - 1고객지원센터(1=있음, 2=없음)',
#        '보유현황 - 2유아놀이방(어린이놀이터)(1=있음, 2=없음)', '보유현황 - 4고객휴게실(1=있음, 2=없음)',
#        '보유현황 - 5수유센터(1=있음, 2=없음)', '보유현황 - 6물품보관함(1=있음, 2=없음)',
#        '보유현황 - 7자전거보관함(1=있음, 2=없음)', '보유현황 - 10쇼핑카트(1=있음, 2=없음)',
#        '문2) 보유현황 - 12고객동선통로(1=있음, 2=없음)', '보유현황 - 16시장전용 고객주차장(1=있음, 2=없음)',
#        '보유갯수 - 16시장전용 고객주차장', '보유여부 - 2소화전(1=있음, 2=없음)', '보유개수-2소화전',
#        '보유여부 - 3공용소화기(1=있음, 2=없음)', '보유개수 - 3공용소화기', '보유여부 - 5경보기(1=있음, 2=없음)',
#        '보유개수 - 5경보기', '화재/가스감지센서(1=있음, 2=없음)', '보유개수 -화재/가스 감지센서',
#        '보유여부 - 7자동 화재속보 설비(1=있음, 2=없음)', '보유개수 - 7자동화재속보설비',
#        '보유여부 - 1CCTV(1=있음, 2=없음)', '보유여부 - 2공동수도시설(노점/장옥형)(1=있음, 2=없음)',
#        '보유여부 - 3공동화장실(1=있음, 2=없음)', '보유개수 -3공동화장실', '보유여부 - 4아케이드(1=있음, 2=없음)',
#        '보유여부 - 5냉방시설(1=있음, 2=없음)', '보유여부 - 6난방시설(1=있음, 2=없음)',
#        '보유여부 - 7가스시설(1=있음, 2=없음)', '보유여부 - 8엘리베이터/에스컬레이터(건물형만)(1=있음, 2=없음)',
#        '보유여부 - 9장애인용 화장실(1=있음, 2=없음)', '보유여부 - 10배수시설(1=있음, 2=없음)',
#        '보유여부 - 11실외 가로등(1=있음, 2=없음)', '보유여부 - 12전기배선시설(1=있음, 2=없음)',
#        '보유여부 - 13건물실내조명 (LED조명 설치 여부)(1=LED조명, 2=형광등 및 백열등)',
#        '보유여부 - 13건물실내조명 (LED조명 설치 여부)(1=LED조명, 2=형광등 및 백열등).1',
#        '보유여부 - 1이동/고정식,이벤트 광장(1=있음, 2=없음)', '보유여부 - 2테마거리(1=있음, 2=없음)',
#        '보유여부 - 3TV광고판(1=있음, 2=없음)', '보유여부 - 4LED광고판(1=있음, 2=없음)',
#        '보유여부 - 6아치/조형물(1=있음, 2=없음)', '시장/상점가의 주력 상품 여부(1=있음, 2=없음)',
#        '시장/상점가의 주력 상품의 개수(1=1개, 2=2개, 3=3개, 4=4개 이상)', '시장/상점가의 주력 상품의 상품명'],
#       dtype='object')

# %%
# 결측치 보기
df2.isnull().sum().plot.barh(figsize=(10,25))
# Out:
# <AxesSubplot:>

# %%
# 주력 상품 결측치 보기

df2["시장/상점가의 주력 상품의 상품명"].isnull().value_counts()
# Out:
# True     1031
# False     419
# Name: 시장/상점가의 주력 상품의 상품명, dtype: int64

# %%
# 사용할 컬럼만 지정
columns2 = ['시장명','시군구','시도', '보유갯수 - 16시장전용 고객주차장',
           '시장/상점가의 주력 상품 여부(1=있음, 2=없음)','보유현황 - 10쇼핑카트(1=있음, 2=없음)',
           '시장/상점가의 주력 상품의 상품명']

# %%
# 컬럼 줄어든 것 확인
df2 = df2[columns2].copy()
df2.shape
# Out:
# (1450, 7)

# %%
# 메모리 줄어든 것 확인
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   시장명                           1450 non-null   object
#  1   시군구                           1450 non-null   object
#  2   시도                            1450 non-null   object
#  3   보유갯수 - 16시장전용 고객주차장           1095 non-null   float64
#  4   시장/상점가의 주력 상품 여부(1=있음, 2=없음)  1450 non-null   int64
#  5   보유현황 - 10쇼핑카트(1=있음, 2=없음)     1450 non-null   int64
#  6   시장/상점가의 주력 상품의 상품명            419 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 79.4+ KB

# %%
# 시도가 서울인 것만 사용

df_seoul = df2[df2["시도"] == "서울"].copy()
df_seoul.shape
# Out:
# (211, 7)

# %%
# 시장명에 '시장'이 들어가는 것만

df_seoul = df_seoul[df_seoul["시장명"].str.contains("시장")]
df_seoul
# Out:
#                  시장명  시군구  시도  보유갯수 - 16시장전용 고객주차장  \
# 848             강남시장  강남구  서울                  1.0
# 849           논현종합시장  강남구  서울                  1.0
# 851           영동전통시장  강남구  서울                  1.0
# 852           청담삼익시장  강남구  서울                  1.0
# 853           고덕전통시장  강동구  서울                  1.0
# ...              ...  ...  ..                  ...
# 1051          면목골목시장  중랑구  서울                  1.0
# 1052            면목시장  중랑구  서울                  1.0
# 1053           사가정시장  중랑구  서울                  NaN
# 1055          우림골목시장  중랑구  서울                  2.0
# 1057  중랑동부시장(동부골목시장)  중랑구  서울                  1.0
#
#       시장/상점가의 주력 상품 여부(1=있음, 2=없음)  보유현황 - 10쇼핑카트(1=있음, 2=없음)  \
# 848                              2                          2
# 849                              2                          2
# 851                              2                          2
# 852                              2                          2
# 853                              2                          2
# ...                            ...                        ...
# 1051                             2                          2
# 1052                             2                          2
# 1053                             2                          2
# 1055                             2                          1
# 1057                             2                          2
#
#      시장/상점가의 주력 상품의 상품명
# 848                 NaN
# 849                 NaN
# 851                 NaN
# 852                 NaN
# 853                 NaN
# ...                 ...
# 1051                NaN
# 1052                NaN
# 1053                NaN
# 1055                NaN
# 1057                NaN
#
# [184 rows x 7 columns]

# %%
df_seoul[df_seoul["시장명"]=="강남시장"]
# Out:
#       시장명  시군구  시도  보유갯수 - 16시장전용 고객주차장  시장/상점가의 주력 상품 여부(1=있음, 2=없음)  \
# 848  강남시장  강남구  서울                  1.0                             2
# 941  강남시장  동작구  서울                  NaN                             2
#
#      보유현황 - 10쇼핑카트(1=있음, 2=없음) 시장/상점가의 주력 상품의 상품명
# 848                          2                NaN
# 941                          2                NaN

# %%
df_mk[df_mk["시장명"]=="강남시장"]
# Out:
#      구   시장명        주소명          경도         위도
# 1  강남구  강남시장  신사동510-11  126.953488  37.496746
# 2  동작구  강남시장    상도동 488  127.020640  37.518749

# %%
# 두 데이터 프레임을 '시장명'을 기준으로 합치기

# 병합할 컬럼의 이름이 '시장명'으로 같으므로 
# left_on='시장명', right_on='시장명' 옵션은 생략

df = pd.merge(df_mk, df_seoul).copy()
df.shape
# Out:
# (145, 11)

# %%
# 두 데이터의 차집합 보기
set(df_mk['시장명'].unique()) - set(df_seoul['시장명'].unique())
# Out:
# {'갈현시장',
#  '강북종합골목시장',
#  '강북종합시장',
#  '고척근린시장',
#  '공릉동 도깨비시장',
#  '공항시장',
#  '관악신사시장(신림4동)',
#  '광장골목시장',
#  '광희시장',
#  '구의시장',
#  '굽은다리골목시장',
#  '금천교시장',
#  '길동골목시장',
#  '깡통시장(제기상가번영회)',
#  '낙성대 시장(봉천7동)',
#  '낙원지하시장(대일상가)',
#  '남구로시장(구 구로자율시장)',
#  '노룬산골목시장',
#  '노룬산시장',
#  '녹번시장',
#  '능동로골목시장',
#  '대명시장',
#  '대명시장 및 주변상점가',
#  '도림시장',
#  '돈암제일시장',
#  '동대문문구완구종합시장',
#  '동문시장',
#  '동부골목시장',
#  '동부청과시장',
#  '동원시장',
#  '동화시장',
#  '두암시장',
#  '면곡골목시장',
#  '명일골목시장',
#  '목동제일시장',
#  '미성동 도깨비시장',
#  '박미시장',
#  '밤나무골시장',
#  '방산시장',
#  '방신재래시장',
#  '방천골목시장',
#  '번동북부골목시장',
#  '번동북부시장',
#  '번동시장',
#  '보문골목시장',
#  '봉천신시장',
#  '사가정골목시장',
#  '사러가시장',
#  '삼선골목시장',
#  '삼성동 시장(신림6동)',
#  '상계시장',
#  '새석관시장',
#  '서중시장',
#  '성내골목시장',
#  '성동용답상가시장',
#  '솔샘시장(미아67동골목시장)',
#  '송화골목시장',
#  '수유전통시장(구)수유골목시장',
#  '수유중앙골목시장',
#  '수일시장',
#  '신길시장',
#  '신노량진시장',
#  '신동시장',
#  '신수시장',
#  '신영사러가시장',
#  '신영시장',
#  '신원시장(신림1동)',
#  '신월3동 골목시장',
#  '신월6동 골목시장',
#  '신월7동 골목시장',
#  '신정1동 골목시장',
#  '신정2동 골목시장',
#  '신정3동 골목시장',
#  '신정제일시장',
#  '신흥시장',
#  '쌍문역골목시장',
#  '쑥고개 시장(봉천8동)',
#  '아리랑시장',
#  '아현골목시장',
#  '양남시장',
#  '양지골목시장',
#  '양지시장',
#  '양지종합시장',
#  '양평시장',
#  '역삼종합시장',
#  '역촌중앙시장',
#  '염리시장',
#  '영등포시장기계공구상가',
#  '영등포시장지하도상점가',
#  '영등포전통시장',
#  '영진시장A동',
#  '영진시장B동',
#  '오류시장',
#  '용문시장',
#  '우리시장',
#  '우이골목시장',
#  '원당종합시장',
#  '유영시장',
#  '응암시장',
#  '인헌시장(봉천11동)',
#  '인현시장',
#  '자양골목시장',
#  '자양종합시장',
#  '장위골목시장',
#  '장위시장',
#  '제기시장',
#  '조광시장',
#  '조양시장',
#  '조원동 펭귄시장(신림8동)',
#  '중곡제일골목시장',
#  '중곡제일시장',
#  '창신골목시장',
#  '청담제일시장',
#  '충신시장',
#  '태능시장',
#  '푸른터시장',
#  '한아름시장',
#  '한양시장',
#  '행당시장',
#  '화곡중앙시장'}

# %%
# 두 데이터의 차집합 보기
set(df_seoul['시장명'].unique()) - set(df_mk['시장명'].unique())
# Out:
# {'㈜사러가시장',
#  '가리봉시장',
#  '강북북부시장',
#  '강북종합전통시장',
#  '고분다리전통시장',
#  '공릉동도깨비시장',
#  '관악신사시장',
#  '길동복조리시장',
#  '남구로시장',
#  '남성시장',
#  '남성역골목시장',
#  '노룬산골목시장(인정시장)',
#  '노룬산시장(건물형)',
#  '돈암시장',
#  '동대문종합시장 신관(동대문쇼핑타운)',
#  '동문시장㈜',
#  '명일전통시장',
#  '방신전통시장',
#  '사가정시장',
#  '상도전통시장',
#  '성내전통시장',
#  '성대전통시장',
#  '수유전통시장(수유골목시장)',
#  '신원시장',
#  '신월1동신영시장',
#  '신중앙시장',
#  '쌍문시장',
#  '아현시장',
#  '용답상가시장',
#  '용문전통시장',
#  '우성상가시장',
#  '은행나무시장',
#  '인헌시장',
#  '자양전통시장',
#  '장위전통시장',
#  '정릉아리랑시장',
#  '조양시장(건물형)',
#  '중곡제일전통시장(중곡제일시장)',
#  '중랑동부시장(동부골목시장)',
#  '청량리농수산물시장',
#  '청량종합도매시장(깡통시장)',
#  '펭귄시장',
#  '황학시장'}

# %%
df["시장/상점가의 주력 상품의 상품명"].isnull().value_counts()
# Out:
# True     114
# False     31
# Name: 시장/상점가의 주력 상품의 상품명, dtype: int64

# %%
df
# Out:
#         구       시장명             주소명          경도         위도   시군구  시도  \
# 0     강남구      강남시장       신사동510-11  126.953488  37.496746   강남구  서울
# 1     강남구      강남시장       신사동510-11  126.953488  37.496746   동작구  서울
# 2     동작구      강남시장         상도동 488  127.020640  37.518749   강남구  서울
# 3     동작구      강남시장         상도동 488  127.020640  37.518749   동작구  서울
# 4     구로구    개봉중앙시장      개봉2동 324-1  126.853884  37.491665   구로구  서울
# ..    ...       ...             ...         ...        ...   ...  ..
# 140   강서구    화곡본동시장       화곡동 98-45  126.844115  37.542868   강서구  서울
# 141   강서구  화곡중앙골목시장  강서구 화곡동 370-37  126.839317  37.535052   강서구  서울
# 142   광진구  화양제일골목시장       화양동 34-72  127.069252  37.543482   광진구  서울
# 143  동대문구      회기시장       회기동 57-22  127.054940  37.590936  동대문구  서울
# 144   용산구      후암시장         후암동 103  126.976553  37.550008   용산구  서울
#
#      보유갯수 - 16시장전용 고객주차장  시장/상점가의 주력 상품 여부(1=있음, 2=없음)  \
# 0                    1.0                             2
# 1                    NaN                             2
# 2                    1.0                             2
# 3                    NaN                             2
# 4                    NaN                             2
# ..                   ...                           ...
# 140                  NaN                             1
# 141                  1.0                             2
# 142                  1.0                             2
# 143                  NaN                             2
# 144                  1.0                             2
#
#      보유현황 - 10쇼핑카트(1=있음, 2=없음) 시장/상점가의 주력 상품의 상품명
# 0                            2                NaN
# 1                            2                NaN
# 2                            2                NaN
# 3                            2                NaN
# 4                            1                NaN
# ..                         ...                ...
# 140                          2            족발  순대국
# 141                          2                NaN
# 142                          2                NaN
# 143                          2                NaN
# 144                          2                NaN
#
# [145 rows x 11 columns]

# %%
import folium

# %%
long = df["경도"].mean()
lat = df["위도"].mean()

# %%
m = folium.Map([lat,long], zoom_start=12)

for i in df.index:
    sub_lat = df.loc[i, "위도"]
    sub_long = df.loc[i, "경도"]
    title = f'{df.loc[i, "시장명"]} ({df.loc[i, "주소명"]})'
    info =  f'{df.loc[i, "시장명"]} (주력 상품: {df.loc[i, "시장/상점가의 주력 상품의 상품명"]})'
    
    icon_color = "red"
    
    folium.Marker([sub_lat, sub_long],
                  icon=folium.Icon(color=icon_color),
                  tooltip=title,
                  popup=f'<i>{info}</i>').add_to(m)

# for문 끝나고 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_00bb4222f4e24435b31587cb44c4996a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_00bb4222f4e24435b31587cb44c4996a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_00bb4222f4e24435b31587cb44c4996a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_00bb4222f4e24435b31587cb44c4996a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.55418009034481%2C%20126.98893741310353%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 다른 스타일
m = folium.Map(location=[lat, long], zoom_start=12, tiles="Stamen Toner")

for i in df.index[:100]:
    tooltip = f'{df.loc[i, "시장명"]} ({df.loc[i, "시장/상점가의 주력 상품의 상품명"]})'
    lat = df.loc[i, "위도"]
    long = df.loc[i, "경도"]

    folium.CircleMarker([lat, long], tooltip=tooltip, radius=3).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4439836237c04013ab02207e1e746f65%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4439836237c04013ab02207e1e746f65%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4439836237c04013ab02207e1e746f65%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4439836237c04013ab02207e1e746f65%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.55418009034481%2C%20126.98893741310353%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 겹친 아이콘 처리
from folium.plugins import MarkerCluster

# icon=folium.Icon(color=icon_color) 로 아이콘 컬러를 변경가능

m = folium.Map([lat,long], zoom_start=12)
marker_cluster = MarkerCluster().add_to(m)

for i in df.index:
    sub_lat = df.loc[i, "위도"]
    sub_long = df.loc[i, "경도"]
    title = f'{df.loc[i, "시장명"]} ({df.loc[i, "주소명"]})'
    info =  f'{df.loc[i, "시장명"]} (주력 상품: {df.loc[i, "시장/상점가의 주력 상품의 상품명"]}, 고객주차장 개수 : {df.loc[i, "보유갯수 - 16시장전용 고객주차장"]}, 쇼핑카트 유무(1=있음, 2=없음) : {df.loc[i, "보유현황 - 10쇼핑카트(1=있음, 2=없음)"]})'
    popup = folium.Popup(f'<i>{info}</i>', max_width=600, max_height=600)
    icon_color = "red"
    
    folium.Marker([sub_lat, sub_long],
                  icon=folium.Icon(color=icon_color),
                  popup=popup, 
                  tooltip=title).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7a8b937c167a474f92091eb9b85ce7e9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7a8b937c167a474f92091eb9b85ce7e9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
# html로 저장

m.save('서울시 전통시장 위치와 편의시설 정보.html')
